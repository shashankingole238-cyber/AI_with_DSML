# %% [markdown]
# **Try 6.5.1: Data exploration in Python.**
#
#
# * The data set below contains data about the energy usage and demands at one of the author's houses.
#
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**
# * **Change the features in the commented scatter plot code to investigate the relationship between two features.**
# * **Change the feature in the commented histogram code to investigate the relationship between two features.**
# **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data
HeatingData = pd.read_csv("Gas Usage.csv")

# %% [markdown]
# ## Understand the data

# %%
HeatingData
# Out:
#                              Date   Gas  Low  Average  High  SolarkWh  \
# 0          Tuesday, July 12, 2022  0.00   62    73.04    82    13.402
# 1           Monday, July 11, 2022  0.00   68    75.35    84     6.814
# 2           Sunday, July 10, 2022  0.00   60    71.17    80    13.158
# 3          Saturday, July 9, 2022  0.00   60    70.71    81    12.726
# 4            Friday, July 8, 2022  0.00   68    73.25    79     5.403
# ..                            ...   ...  ...      ...   ...       ...
# 513     Sunday, February 14, 2021  5.02   -3     3.08    10     0.013
# 514   Saturday, February 13, 2021  4.40   -9    -2.33     5     0.072
# 515     Friday, February 12, 2021  6.42   -7    -0.22     5     0.001
# 516   Thursday, February 11, 2021  6.22  -17    -8.62    -3     0.028
# 517  Wednesday, February 10, 2021  5.34  -11    -0.46     5     0.000
#
#      FireHrs  AwayHrs  PanelsFree  ConsumptionkWh  HotWaterkWh  Guests
# ...

# %% [markdown]
# ## Data description
#
# * **Date : The day for the energy usage**
#
# * **Gas : The amount of natural gas used in therms**
#
# * **Low : The low temperature for the day in Fahrenheit**
#
# * **Average : The average temperature for the day in Fahrenheit**
#
# * **High : The high temperature for the day in Fahrenheit**
#
# * **SolarkWh : The amount of electricity generated by the solar panels in kWh**
#
# * **FireHrs : Duration of the fire in the woodstove in hours**
#
# * **AwayHrs : Number of hours the thermostat was setback to the away temperature**
#
# * **PanelsFree : The proportion of the solar panels that is not covered with snow**
#
# * **ConsumptionkWh : The amount of electricity consumed by the household in kWh**
#
# * **HotWaterkWh : The amount of electricity consumed by the heat pump water heater in kWh**
#
# * **Guests: Whether guests stayed at the house. (0 = no guests, 1 = guests visited)**

# %%
HeatingData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518 entries, 0 to 517
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            518 non-null    object
#  1   Gas             518 non-null    float64
#  2   Low             518 non-null    int64
#  3   Average         518 non-null    float64
#  4   High            518 non-null    int64
#  5   SolarkWh        518 non-null    float64
#  6   FireHrs         518 non-null    float64
#  7   AwayHrs         518 non-null    float64
#  8   PanelsFree      518 non-null    float64
#  9   ConsumptionkWh  518 non-null    float64
#  10  HotWaterkWh     517 non-null    float64
#  11  Guests          518 non-null    int64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 48.7+ KB

# %% [markdown]
# Guests is the only categorical variable.

# %% [markdown]
# ## Identify relationships between features

# %%
# Set the figure dimensions to 15 by 8
sns.set_theme(rc={'figure.figsize': (15, 8)})
pd.plotting.scatter_matrix(HeatingData)
plt.show()

# %%
# Uncomment the line below to investigate relationships between variables.

sns.scatterplot(data = HeatingData, x="Average", y="Gas")
# Out:
# <Axes: xlabel='Average', ylabel='Gas'>

# %% [markdown]
# #### Replace with a description of what you found.

# %% [markdown]
# <!-- Replace with a description of what you found. -->

# %% [markdown]
# ## Describe the shape of data

# %%
HeatingData.hist()
plt.show()

# %% [markdown]
# Gas is right-skewed. The rest are interestingly distributed. The fact that the data starts in February and ends in the following July may be leading to some artifacts on the temperature distributions.

# %%
#Uncomment the line below and investigate FireHrs or PanelsFree
sns.histplot(data = HeatingData, x = 'FireHrs')
# Out:
# <Axes: xlabel='FireHrs', ylabel='Count'>

# %% [markdown]
# Edit this to describe what you observe

# %% [markdown]
# ## Detect outliers and missing data

# %%
HeatingData.describe()
# Out:
#               Gas         Low     Average        High    SolarkWh     FireHrs  \
# count  518.000000  518.000000  518.000000  518.000000  518.000000  518.000000
# mean     0.982741   40.055985   48.971699   57.689189    8.216624    1.057915
# std      1.355696   21.510979   21.710003   22.850915    4.693557    3.426561
# min      0.000000  -17.000000   -8.620000   -4.000000    0.000000    0.000000
# 25%      0.000000   27.000000   34.197500   41.000000    4.215500    0.000000
# 50%      0.250000   41.000000   50.390000   60.000000    9.018500    0.000000
# 75%      1.660000   59.000000   68.587500   78.000000   12.405500    0.000000
# max      6.790000   83.000000   83.830000   95.000000   16.235000   21.000000
#
#           AwayHrs  PanelsFree  ConsumptionkWh  HotWaterkWh      Guests
# count  518.000000  518.000000      518.000000   517.000000  518.000000
# mean     4.860521    0.918142       12.178863     1.245397    0.061776
# ...

# %% [markdown]
# Based on the counts the data looks complete, with the exception of one day for the hot water heater. The hot water heater may also have an outlier because the max is pretty high in comparison to the other statistics.
